# %%
import pandas as pd
generate_car_matrix = pd.read_csv(r'D:\Suhani\Projects\dataset-1.csv')
generate_car_matrix = pd.DataFrame(generate_car_matrix)
generate_car_matrix.head()
# Out:
#    id_1  id_2  route   moto    car     rv   bus  truck
# 0   829   827      1   2.05   4.14   4.14  10.1   15.2
# 1   829   821      4   6.63  13.26  13.26  32.4   48.5
# 2   829   804      7  14.41  28.92  28.92  64.7   97.0
# 3   829   822      6   5.90  11.81  11.81  28.8   43.2
# 4   829   826      9   2.87   5.81   5.81  14.2   21.2

# %%
#Question 1
df = pd.pivot_table(generate_car_matrix, index = 'id_1', 
                    columns = 'id_2', values='car',fill_value=0)
df
# Out:
# id_2    801    802    803    804    805    806    807    808    809    821  \
# id_1
# 801    0.00   2.80   6.00   7.70  11.70  13.40  16.90  19.60  21.00  23.52
# 802    2.80   0.00   3.40   5.20   9.20  10.90  14.30  17.10  18.50  20.92
# 803    6.00   3.40   0.00   2.00   6.00   7.70  11.10  13.90  15.30  17.72
# 804    7.70   5.20   2.00   0.00   4.40   6.10   9.50  12.30  13.70  16.12
# 805   11.70   9.20   6.00   4.40   0.00   2.00   5.40   8.20   9.60  12.02
# 806   13.40  10.90   7.70   6.10   2.00   0.00   3.80   6.60   8.00  10.42
# 807   16.90  14.30  11.10   9.50   5.40   3.80   0.00   2.90   4.30   6.82
# 808   19.60  17.10  13.90  12.30   8.20   6.60   2.90   0.00   1.70   4.12
# 809   21.00  18.50  15.30  13.70   9.60   8.00   4.30   1.70   0.00   2.92
# 821   23.52  20.92  17.72  16.12  12.02  10.42   6.82   4.12   2.92   0.00
# 822   24.67  22.07  18.87  17.27  13.17  11.57   7.97   5.27   4.07   1.80
# ...

# %%
#Question 2
get_type_count = pd.read_csv(r'D:\Suhani\Projects\dataset-1.csv')
get_type_count.head()
# Out:
#    id_1  id_2  route   moto    car     rv   bus  truck
# 0   829   827      1   2.05   4.14   4.14  10.1   15.2
# 1   829   821      4   6.63  13.26  13.26  32.4   48.5
# 2   829   804      7  14.41  28.92  28.92  64.7   97.0
# 3   829   822      6   5.90  11.81  11.81  28.8   43.2
# 4   829   826      9   2.87   5.81   5.81  14.2   21.2

# %%
conditions = [
    (get_type_count['car']<=15),
    (get_type_count['car']>15) & (get_type_count['car']<=25),
    (get_type_count['car']>25)
]
values = ['low', 'medium', 'high']

import numpy as np 
get_type_count['car_type']=np.select(conditions,values)
get_type_count.head(15)
# Out:
#     id_1  id_2  route   moto    car     rv   bus   truck car_type
# 0    829   827      1   2.05   4.14   4.14  10.1   15.20      low
# 1    829   821      4   6.63  13.26  13.26  32.4   48.50      low
# 2    829   804      7  14.41  28.92  28.92  64.7   97.00     high
# 3    829   822      6   5.90  11.81  11.81  28.8   43.20      low
# 4    829   826      9   2.87   5.81   5.81  14.2   21.20      low
# 5    829   807      2   9.81  19.62  19.62  46.0   69.00   medium
# 6    829   809      4   7.91  15.72  15.72  38.4   57.50   medium
# 7    829   801      1  18.21  36.32  36.32  79.5  119.20     high
# 8    829   824      7   8.77  21.40  21.40  32.1    4.35   medium
# 9    829   823      4   5.00  10.00  10.00  24.4   36.60      low
# 10   829   831      9   1.72   3.36   3.36   8.3   12.40      low
# 11   829   808      5   8.51  16.92  16.92  40.7   61.00   medium
# 12   829   802      5  16.91  33.72  33.72  74.3  111.40     high
# ...

# %%
#Question 3
get_bus_indexes = pd.read_csv(r'D:\Suhani\Projects\dataset-1.csv')
get_bus_indexes.sort_values('bus')
# Out:
#      id_1  id_2  route   moto    car     rv   bus  truck
# 137   809   808      3   0.80   1.70   1.70   3.3    5.0
# 223   808   809      9   0.80   1.70   1.70   3.3    5.0
# 214   831   830      1   0.74   1.39   1.39   3.5    5.2
# 317   830   831      5   0.74   1.39   1.39   3.5    5.2
# 71    804   803      5   1.00   2.00   2.00   3.9    5.9
# ..    ...   ...    ...    ...    ...    ...   ...    ...
# 210   831   802      7  18.37  36.64  36.64  81.3  122.0
# 160   801   830      9  19.18  38.27  38.27  84.2  126.2
# 314   830   801      9  19.18  38.27  30.27  84.2  126.2
# 154   801   831      4  19.67  39.24  39.24  86.5  129.8
# 206   831   801      2  19.67  39.24  39.24  86.5  129.8
#
# [341 rows x 8 columns]

# %%
#Question 4
filter_routes = pd.read_csv(r'D:\Suhani\Projects\dataset-1.csv')
sort_values=filter_routes.sort_values('route')
sort_values.head()
# Out:
#      id_1  id_2  route   moto    car     rv   bus  truck
# 0     829   827      1   2.05   4.14   4.14  10.1   15.2
# 176   824   825      1   0.82   1.71   1.71   4.2    6.3
# 171   824   823      1   0.90   1.79   1.79   4.4    6.6
# 156   801   802      1   1.40   2.80   2.80   5.5    8.3
# 151   801   809      1  10.50  21.00  21.00  42.1   63.1

# %%
sort_values['truck'].mean()
# Out:
# 47.841788856304994

# %%
#Question 5
multiply_matrix=generate_car_matrix
conditions_1 = [
    (multiply_matrix['car']>20),
    (multiply_matrix['car']<=20)
]
values_1 = [multiply_matrix['car']*0.75, multiply_matrix['car']*1.25]

multiply_matrix['modified_values']=np.select(conditions_1, values_1)

modified_df = pd.pivot_table(multiply_matrix, index = 'id_1', 
                    columns = 'id_2', values='modified_values',fill_value=0)
modified_df.head()
# Out:
# id_2     801    802   803    804     805     806     807     808     809  \
# id_1
# 801    0.000   3.50  7.50  9.625  14.625  16.750  21.125  24.500  15.750
# 802    3.500   0.00  4.25  6.500  11.500  13.625  17.875  21.375  23.125
# 803    7.500   4.25  0.00  2.500   7.500   9.625  13.875  17.375  19.125
# 804    9.625   6.50  2.50  0.000   5.500   7.625  11.875  15.375  17.125
# 805   14.625  11.50  7.50  5.500   0.000   2.500   6.750  10.250  12.000
#
# id_2     821      822      823     824     825      826      827     829  \
# id_1
# 801   17.640  18.5025  19.8975  20.940  21.810  23.1525  24.3975  27.240
# 802   15.690  16.5525  17.9475  18.990  19.860  21.2025  22.4475  25.290
# 803   22.150  23.5875  15.5475  16.590  17.460  18.8025  20.0475  22.890
# 804   20.150  21.5875  23.9125  15.390  16.260  17.6025  18.8475  21.690
# 805   15.025  16.4625  18.7875  20.525  21.975  24.2125  15.7725  18.615
#
# id_2      830     831
# id_1
# 801   28.7025  29.430
# ...
